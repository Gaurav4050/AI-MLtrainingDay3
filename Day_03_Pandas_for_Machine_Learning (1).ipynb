# %% [markdown]
# # **PANDAS For Machine Learning**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pandas is an open-source python package built on top of Numpy developed by Wes McKinney. It is used as one of the most important data cleaning and analysis tool. It provides fast, flexible, and expressive data structures.
#
# Pandas is derived from the term “Panel-data-s” an econometrics term for data sets include observations over multiple time periods for the same individuals. -source Wikipedia

# %% [markdown]
# **How to import Pandas?**
#
# import pandas as pd

# %% [markdown]
# **Pandas Data Structures**
#
# *Pandas deals with three types of data structures :*
#
# Series
#
# DataFrame
#
# Panel

# %% [markdown]
# **Series **
#
# It is a one-dimensional array-like structure with homogeneous data. The size of the series is immutable(cannot be changed) but its values are mutable.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **DataFrame **
#
# It is a two-dimensional array-like structure with heterogeneous data. Data is aligned in a tabular manner(Rows &Columns form). The size and values of DataFrame are mutable.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Panel **
#
# It is a three-dimensional data structure with heterogeneous data. It is hard to represent the panel in graphical representation. But it can be illustrated as a container of DataFrame. The size and values of a Panel are mutable.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Working with Series

# %%
ser1 = pd.Series(data=[1,2,3,4,5], index=list('abcde'))

ser1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
ser1['d']
# Out:
# 4

# %%
ser2 = pd.Series(data=[11,22,33,44,55], index=list('abcde'))

print(ser2)
# Out:
# a    11
# b    22
# c    33
# d    44
# e    55
# dtype: int64

# %% [markdown]
# # **DataFrame**

# %% [markdown]
# Creating DataFrame from above two series
#
# Data corresponding to same index belongs to same row

# %%
df=pd.DataFrame({'A':ser1, 'B':ser2})

df
# Out:
#    A   B
# a  1  11
# b  2  22
# c  3  33
# d  4  44
# e  5  55

# %% [markdown]
# Creating a random dataframe of 10 X 10

# %%
pd.DataFrame(data=np.random.randint(1,10,size=(10,10)), index=list('ABCDEFGHIJ'),columns=list('abcdefghij'))
# Out:
#    a  b  c  d  e  f  g  h  i  j
# A  9  5  3  6  5  1  8  5  3  7
# B  9  1  6  5  7  2  5  6  8  8
# C  8  5  4  8  6  2  6  4  9  7
# D  9  4  2  3  4  2  2  2  3  6
# E  3  4  2  2  9  5  8  6  7  6
# F  7  8  3  4  6  8  3  3  5  4
# G  7  2  7  4  2  5  9  6  3  1
# H  2  4  2  8  6  1  6  4  2  7
# I  2  7  4  2  2  9  6  6  3  8
# J  8  9  6  4  9  7  3  9  9  2

# %% [markdown]
# Loading csv, json

# %%
pd_data = pd.read_csv('https://raw.githubusercontent.com/zekelabs/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt')

# %%
pd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
pd_data.head()
# Out:
#    satisfaction_level  last_evaluation  ...  sales  salary
# 0                0.38             0.53  ...  sales     low
# 1                0.80             0.86  ...  sales  medium
# 2                0.11             0.88  ...  sales  medium
# 3                0.72             0.87  ...  sales     low
# 4                0.37             0.52  ...  sales     low
#
# [5 rows x 10 columns]

# %%
pd.read_json('https://raw.githubusercontent.com/zekelabs/data-science-complete-tutorial/master/Data/movie.json.txt')
# Out:
#                David Smith  Brenda Peterson  ...  Adam Cohen  Chris Duncan
# Vertigo                4.0              3.0  ...         3.5           NaN
# Scarface               4.5              1.5  ...         3.0           NaN
# Raging Bull            3.0              1.0  ...         NaN           4.5
# Goodfellas             4.5              2.0  ...         4.5           NaN
# The Apartment          1.0              5.0  ...         1.0           1.5
# Roman Holiday          NaN              4.5  ...         3.0           NaN
#
# [6 rows x 8 columns]

# %% [markdown]
# **Descriptive Statistics**

# %% [markdown]
# Pandas api's for understanding data

# %%
pd_data = pd.read_csv('https://raw.githubusercontent.com/zekelabs/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt')

# %%
pd_data.head(10)
# Out:
#    satisfaction_level  last_evaluation  ...  sales  salary
# 0                0.38             0.53  ...  sales     low
# 1                0.80             0.86  ...  sales  medium
# 2                0.11             0.88  ...  sales  medium
# 3                0.72             0.87  ...  sales     low
# 4                0.37             0.52  ...  sales     low
# 5                0.41             0.50  ...  sales     low
# 6                0.10             0.77  ...  sales     low
# 7                0.92             0.85  ...  sales     low
# 8                0.89             1.00  ...  sales     low
# 9                0.42             0.53  ...  sales     low
#
# [10 rows x 10 columns]

# %%
pd_data.tail(2)
# Out:
#        satisfaction_level  last_evaluation  ...    sales  salary
# 14997                0.11             0.96  ...  support     low
# 14998                0.37             0.52  ...  support     low
#
# [2 rows x 10 columns]

# %%
pd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
pd_data.describe()
# Out:
#        satisfaction_level  last_evaluation  ...          left  promotion_last_5years
# count        14999.000000     14999.000000  ...  14999.000000           14999.000000
# mean             0.612834         0.716102  ...      0.238083               0.021268
# std              0.248631         0.171169  ...      0.425924               0.144281
# min              0.090000         0.360000  ...      0.000000               0.000000
# 25%              0.440000         0.560000  ...      0.000000               0.000000
# 50%              0.640000         0.720000  ...      0.000000               0.000000
# 75%              0.820000         0.870000  ...      0.000000               0.000000
# max              1.000000         1.000000  ...      1.000000               1.000000
#
# [8 rows x 8 columns]

# %%
pd_data.salary.value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %% [markdown]
# **Filtering data using row and column**

# %%
col_data=pd_data.select_dtypes('object')

# %%
col_data.head()
# Out:
#   Department  salary
# 0      sales     low
# 1      sales  medium
# 2      sales  medium
# 3      sales     low
# 4      sales     low

# %% [markdown]
# Column rename

# %%
pd_data.rename(columns={'sales':'Department'}, inplace=True)

# %%
pd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
pd_data[['satisfaction_level','last_evaluation','number_project']].head()
# Out:
#    satisfaction_level  last_evaluation  number_project
# 0                0.38             0.53               2
# 1                0.80             0.86               5
# 2                0.11             0.88               7
# 3                0.72             0.87               5
# 4                0.37             0.52               2

# %%
pd_data.satisfaction_level[0:3]
# Out:
# 0    0.38
# 1    0.80
# 2    0.11
# Name: satisfaction_level, dtype: float64

# %%
pd_data['satisfaction_level'][0:3]
# Out:
# 0    0.38
# 1    0.80
# 2    0.11
# Name: satisfaction_level, dtype: float64

# %%
mov_data=pd.read_json('https://raw.githubusercontent.com/zekelabs/data-science-complete-tutorial/master/Data/movie.json.txt')

# %%
mov_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Vertigo to Roman Holiday
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   David Smith       5 non-null      float64
#  1   Brenda Peterson   6 non-null      float64
#  2   Bill Duffy        4 non-null      float64
#  3   Samuel Miller     5 non-null      float64
#  4   Julie Hammel      3 non-null      float64
#  5   Clarissa Jackson  6 non-null      float64
#  6   Adam Cohen        5 non-null      float64
#  7   Chris Duncan      2 non-null      float64
# dtypes: float64(8)
# memory usage: 432.0+ bytes

# %%
mov_data.head(6)
# Out:
#                David Smith  Brenda Peterson  ...  Adam Cohen  Chris Duncan
# Vertigo                4.0              3.0  ...         3.5           NaN
# Scarface               4.5              1.5  ...         3.0           NaN
# Raging Bull            3.0              1.0  ...         NaN           4.5
# Goodfellas             4.5              2.0  ...         4.5           NaN
# The Apartment          1.0              5.0  ...         1.0           1.5
# Roman Holiday          NaN              4.5  ...         3.0           NaN
#
# [6 rows x 8 columns]

# %% [markdown]
# **Access data by index values**

# %%
mov_data.loc['Scarface':'Raging Bull']
# Out:
#              David Smith  Brenda Peterson  ...  Adam Cohen  Chris Duncan
# Scarface             4.5              1.5  ...         3.0           NaN
# Raging Bull          3.0              1.0  ...         NaN           4.5
#
# [2 rows x 8 columns]

# %%
mov_data.iloc[1:3]
# Out:
#              David Smith  Brenda Peterson  ...  Adam Cohen  Chris Duncan
# Scarface             4.5              1.5  ...         3.0           NaN
# Raging Bull          3.0              1.0  ...         NaN           4.5
#
# [2 rows x 8 columns]

# %% [markdown]
# Filtering based on certain conditions

# %%
mov_data[(mov_data['Adam Cohen']>3) | (mov_data['David Smith']>4)]
# Out:
#             David Smith  Brenda Peterson  ...  Adam Cohen  Chris Duncan
# Vertigo             4.0              3.0  ...         3.5           NaN
# Scarface            4.5              1.5  ...         3.0           NaN
# Goodfellas          4.5              2.0  ...         4.5           NaN
#
# [3 rows x 8 columns]
